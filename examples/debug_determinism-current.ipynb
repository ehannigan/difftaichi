# %% [markdown]
# # mass_spring.py

# %% [markdown]
# Changes: Only changes are that I reduced num optimization iters to be 10 and I turned off visualization.
#
# Observation: Weight initializations are the same between runs. However, the loss output is different.

# %% [markdown]
# ### Run 1:

# %%
# %run -i mass_spring.py 2 train
# Out:
# [Taichi] mode=release
# [Taichi] preparing sandbox at /var/folders/hm/8lv3n72d13756xxcw59843d82j2gcf/T/taichi-216vqzym
# [Taichi] version 0.6.28, llvm 10.0.0, commit 2670350d, osx, python 3.7.3
# [Taichi] Starting on arch=x64
# n_objects= 20    n_springs= 46
# [Taichi] materializing...
# weights1 [[ 0.44806975  0.10164003  0.2485997  ...  0.267831   -0.10240705
#    0.31050137]
#  [ 0.0529019   0.24806656  0.09051716 ... -0.34923798 -0.16347924
#   -0.56474495]
#  [ 0.15880895 -0.40692306 -0.28051364 ...  0.0990838  -0.16571194
#   -0.09930225]
#  ...
#  [ 0.16512163  0.46251905 -0.19819129 ... -0.22837491  0.21273738
#    0.49806422]
#  [ 0.12008869 -0.1338814  -0.13621275 ... -0.14308073  0.17202063
#   -0.00810542]
#  [-0.04409654  0.22815335 -0.05023806 ... -0.35711598  0.29957297
#    0.21250576]]
# weights2 [[ 6.6651061e-02 -6.1216325e-01 -6.7365777e-01 ... -1.8233190e-01
#    9.5787257e-02  9.3471354e-01]
#  [ 2.7427542e-01  5.1511657e-01 -2.4197419e-01 ... -1.8914355e-01
# ...

# %% [markdown]
# ### Run 2:

# %%
# %run -i mass_spring.py 2 train
# Out:
# [Taichi] Starting on arch=x64
# n_objects= 20    n_springs= 46
# [Taichi] materializing...
# weights1 [[ 0.44806975  0.10164003  0.2485997  ...  0.267831   -0.10240705
#    0.31050137]
#  [ 0.0529019   0.24806656  0.09051716 ... -0.34923798 -0.16347924
#   -0.56474495]
#  [ 0.15880895 -0.40692306 -0.28051364 ...  0.0990838  -0.16571194
#   -0.09930225]
#  ...
#  [ 0.16512163  0.46251905 -0.19819129 ... -0.22837491  0.21273738
#    0.49806422]
#  [ 0.12008869 -0.1338814  -0.13621275 ... -0.14308073  0.17202063
#   -0.00810542]
#  [-0.04409654  0.22815335 -0.05023806 ... -0.35711598  0.29957297
#    0.21250576]]
# weights2 [[ 6.6651061e-02 -6.1216325e-01 -6.7365777e-01 ... -1.8233190e-01
#    9.5787257e-02  9.3471354e-01]
#  [ 2.7427542e-01  5.1511657e-01 -2.4197419e-01 ... -1.8914355e-01
#    4.0954012e-02  4.7760777e-02]
#  [-7.3528427e-01  1.5738508e-01  1.3412166e-01 ... -5.6515944e-01
#   -6.1527961e-01  7.9823172e-01]
#  ...
# ...

# %% [markdown]
# # mass_spring_f64.py

# %% [markdown]
# Changes: Changed real=ti.f32 to real=ti.f64.
#
# Observation: Weight initialization are the same between runs. Loss outputs are different.

# %% [markdown]
# ### Run 1:

# %%
# %run -i mass_spring_f64.py 2 train
# Out:
# [Taichi] Starting on arch=x64
# n_objects= 20    n_springs= 46
# [Taichi] materializing...
# weights1 [[ 0.44806974  0.10164003  0.2485997  ...  0.26783101 -0.10240705
#    0.31050136]
#  [ 0.0529019   0.24806656  0.09051716 ... -0.34923798 -0.16347924
#   -0.56474497]
#  [ 0.15880895 -0.40692305 -0.28051365 ...  0.0990838  -0.16571195
#   -0.09930226]
#  ...
#  [ 0.16512163  0.46251904 -0.19819128 ... -0.22837491  0.21273738
#    0.49806422]
#  [ 0.12008869 -0.1338814  -0.13621275 ... -0.14308072  0.17202063
#   -0.00810542]
#  [-0.04409654  0.22815335 -0.05023806 ... -0.357116    0.29957297
#    0.21250575]]
# weights2 [[ 6.66510628e-02 -6.12163223e-01 -6.73657798e-01 ... -1.82331902e-01
#    9.57872554e-02  9.34713538e-01]
#  [ 2.74275431e-01  5.15116569e-01 -2.41974187e-01 ... -1.89143557e-01
#    4.09540121e-02  4.77607775e-02]
#  [-7.35284260e-01  1.57385085e-01  1.34121657e-01 ... -5.65159423e-01
#   -6.15279644e-01  7.98231734e-01]
#  ...
# ...

# %% [markdown]
# ### Run 2:

# %%
# %run -i mass_spring_f64.py 2 train
# Out:
# [Taichi] Starting on arch=x64
# n_objects= 20    n_springs= 46
# [Taichi] materializing...
# weights1 [[ 0.44806974  0.10164003  0.2485997  ...  0.26783101 -0.10240705
#    0.31050136]
#  [ 0.0529019   0.24806656  0.09051716 ... -0.34923798 -0.16347924
#   -0.56474497]
#  [ 0.15880895 -0.40692305 -0.28051365 ...  0.0990838  -0.16571195
#   -0.09930226]
#  ...
#  [ 0.16512163  0.46251904 -0.19819128 ... -0.22837491  0.21273738
#    0.49806422]
#  [ 0.12008869 -0.1338814  -0.13621275 ... -0.14308072  0.17202063
#   -0.00810542]
#  [-0.04409654  0.22815335 -0.05023806 ... -0.357116    0.29957297
#    0.21250575]]
# weights2 [[ 6.66510628e-02 -6.12163223e-01 -6.73657798e-01 ... -1.82331902e-01
#    9.57872554e-02  9.34713538e-01]
#  [ 2.74275431e-01  5.15116569e-01 -2.41974187e-01 ... -1.89143557e-01
#    4.09540121e-02  4.77607775e-02]
#  [-7.35284260e-01  1.57385085e-01  1.34121657e-01 ... -5.65159423e-01
#   -6.15279644e-01  7.98231734e-01]
#  ...
# ...

# %% [markdown]
# # mass_spring_f64_check_float.py

# %% [markdown]
#  Changes: Same as mass_spring_f64, but also made sure all numbers that are supposed to be floats have a decimal (ex. 2 -> 2.0)
#  Observation: No change from mass_spring_f64.py results

# %% [markdown]
# ### Run 1:

# %%
# %run -i mass_spring_f64_check_float.py 2 train
# Out:
# [Taichi] Starting on arch=x64
# n_objects= 20    n_springs= 46
# [Taichi] materializing...
# weights1 [[ 0.44806974  0.10164003  0.2485997  ...  0.26783101 -0.10240705
#    0.31050136]
#  [ 0.0529019   0.24806656  0.09051716 ... -0.34923798 -0.16347924
#   -0.56474497]
#  [ 0.15880895 -0.40692305 -0.28051365 ...  0.0990838  -0.16571195
#   -0.09930226]
#  ...
#  [ 0.16512163  0.46251904 -0.19819128 ... -0.22837491  0.21273738
#    0.49806422]
#  [ 0.12008869 -0.1338814  -0.13621275 ... -0.14308072  0.17202063
#   -0.00810542]
#  [-0.04409654  0.22815335 -0.05023806 ... -0.357116    0.29957297
#    0.21250575]]
# weights2 [[ 6.66510628e-02 -6.12163223e-01 -6.73657798e-01 ... -1.82331902e-01
#    9.57872554e-02  9.34713538e-01]
#  [ 2.74275431e-01  5.15116569e-01 -2.41974187e-01 ... -1.89143557e-01
#    4.09540121e-02  4.77607775e-02]
#  [-7.35284260e-01  1.57385085e-01  1.34121657e-01 ... -5.65159423e-01
#   -6.15279644e-01  7.98231734e-01]
#  ...
# ...

# %% [markdown]
# ### Run 2:

# %%
# %run -i mass_spring_f64.py 2 train
# Out:
# [Taichi] Starting on arch=x64
# n_objects= 20    n_springs= 46
# [Taichi] materializing...
# weights1 [[ 0.44806974  0.10164003  0.2485997  ...  0.26783101 -0.10240705
#    0.31050136]
#  [ 0.0529019   0.24806656  0.09051716 ... -0.34923798 -0.16347924
#   -0.56474497]
#  [ 0.15880895 -0.40692305 -0.28051365 ...  0.0990838  -0.16571195
#   -0.09930226]
#  ...
#  [ 0.16512163  0.46251904 -0.19819128 ... -0.22837491  0.21273738
#    0.49806422]
#  [ 0.12008869 -0.1338814  -0.13621275 ... -0.14308072  0.17202063
#   -0.00810542]
#  [-0.04409654  0.22815335 -0.05023806 ... -0.357116    0.29957297
#    0.21250575]]
# weights2 [[ 6.66510628e-02 -6.12163223e-01 -6.73657798e-01 ... -1.82331902e-01
#    9.57872554e-02  9.34713538e-01]
#  [ 2.74275431e-01  5.15116569e-01 -2.41974187e-01 ... -1.89143557e-01
#    4.09540121e-02  4.77607775e-02]
#  [-7.35284260e-01  1.57385085e-01  1.34121657e-01 ... -5.65159423e-01
#   -6.15279644e-01  7.98231734e-01]
#  ...
# ...

# %% [markdown]
# # mass_spring_f64_i64.py

# %% [markdown]
# Changes: Specified the use of i64 instead of i32 in case that reverted some of the floats back to f32
#
# Observation: Error - Assertion failed: (S1->getType() == S2->getType() && "Cannot create binary operator with two operands of differing type!"), function Create, file /Users/th3charlie/dev/taichi-exp/llvm/lib/IR/Instructions.cpp, line 2334.
# [E 08/19/20 21:51:21.766] Received signal 6 (Abort trap: 6)

# %% [markdown]
# ### Run 1:

# %%
# %run -i mass_spring_f64_i64.py 2 train
# Out:
# [Taichi] mode=release
# [Taichi] preparing sandbox at /var/folders/hm/8lv3n72d13756xxcw59843d82j2gcf/T/taichi-u_4jvdbv
# [Taichi] version 0.6.28, llvm 10.0.0, commit 2670350d, osx, python 3.7.3
# [Taichi] Starting on arch=x64
# n_objects= 20    n_springs= 46
# [Taichi] materializing...
# weights1 [[ 0.44806974  0.10164003  0.2485997  ...  0.26783101 -0.10240705
#    0.31050136]
#  [ 0.0529019   0.24806656  0.09051716 ... -0.34923798 -0.16347924
#   -0.56474497]
#  [ 0.15880895 -0.40692305 -0.28051365 ...  0.0990838  -0.16571195
#   -0.09930226]
#  ...
#  [ 0.16512163  0.46251904 -0.19819128 ... -0.22837491  0.21273738
#    0.49806422]
#  [ 0.12008869 -0.1338814  -0.13621275 ... -0.14308072  0.17202063
#   -0.00810542]
#  [-0.04409654  0.22815335 -0.05023806 ... -0.357116    0.29957297
#    0.21250575]]
# weights2 [[ 6.66510628e-02 -6.12163223e-01 -6.73657798e-01 ... -1.82331902e-01
#    9.57872554e-02  9.34713538e-01]
# ...

# %% [markdown]
# Assertion failed: (S1->getType() == S2->getType() && "Cannot create binary operator with two operands of differing type!"), function Create, file /Users/th3charlie/dev/taichi-exp/llvm/lib/IR/Instructions.cpp, line 2334.
# [E 08/19/20 22:14:05.226] Received signal 6 (Abort trap: 6)
#
#
#
#                             * Taichi Core - Stack Traceback *
# ==========================================================================================
# |                       Module |  Offset | Function                                      |
# |----------------------------------------------------------------------------------------|
# *               taichi_core.so |     324 | taichi::signal_handler(int)                   |
# *     libsystem_platform.dylib |      29 | (null)                                        |
# *                          ??? |      -1 | (null)                                        |
# *            libsystem_c.dylib |     120 | (null)                                        |
# *            libsystem_c.dylib |       0 | (null)                                        |
# *               taichi_core.so |      35 | llvm::BinaryOperator::Create(llvm::Instructio |
#                                          | n::BinaryOps, llvm::Value*, llvm::Value*, llv |
#                                          | m::Twine const&, llvm::Instruction*) (.cold.1 |
#                                          | )                                             |
# *               taichi_core.so |     110 | llvm::BinaryOperator::Create(llvm::Instructio |
#                                          | n::BinaryOps, llvm::Value*, llvm::Value*, llv |
#                                          | m::Twine const&, llvm::Instruction*)          |
# *               taichi_core.so |     145 | llvm::IRBuilder<llvm::ConstantFolder, llvm::I |
#                                          | RBuilderDefaultInserter>::CreateAnd(llvm::Val |
#                                          | ue*, llvm::Value*, llvm::Twine const&)        |
# *               taichi_core.so |     167 | taichi::lang::CodeGenLLVM::visit(taichi::lang |
#                                          | ::BitExtractStmt*)                            |
# *               taichi_core.so |      43 | taichi::lang::CodeGenLLVM::visit(taichi::lang |
#                                          | ::Block*)                                     |
# *               taichi_core.so |     786 | taichi::lang::CodeGenLLVMCPU::create_offload_ |
#                                          | range_for(taichi::lang::OffloadedStmt*)       |
# *               taichi_core.so |    1159 | taichi::lang::CodeGenLLVMCPU::visit(taichi::l |
#                                          | ang::OffloadedStmt*)                          |
# *               taichi_core.so |      43 | taichi::lang::CodeGenLLVM::visit(taichi::lang |
#                                          | ::Block*)                                     |
# *               taichi_core.so |     103 | taichi::lang::CodeGenLLVM::emit_to_module()   |
# *               taichi_core.so |      25 | taichi::lang::CodeGenLLVM::gen()              |
# *               taichi_core.so |     123 | taichi::lang::CodeGenCPU::codegen()           |
# *               taichi_core.so |      97 | taichi::lang::KernelCodeGen::compile()        |
# *               taichi_core.so |     251 | taichi::lang::Program::compile(taichi::lang:: |
#                                          | Kernel&)                                      |
# *               taichi_core.so |      62 | taichi::lang::Kernel::compile()               |
# *               taichi_core.so |     125 | taichi::lang::Kernel::operator()(taichi::lang |
#                                          | ::Kernel::LaunchContextBuilder&)              |
# *               taichi_core.so |     180 | void pybind11::cpp_function::initialize<taich |
#                                          | i::export_lang(pybind11::module&)::$_9, void, |
#                                          |  taichi::lang::Kernel*, taichi::lang::Kernel: |
#                                          | :LaunchContextBuilder&, pybind11::name, pybin |
#                                          | d11::is_method, pybind11::sibling>(taichi::ex |
#                                          | port_lang(pybind11::module&)::$_9&&, void (*) |
#                                          | (taichi::lang::Kernel*, taichi::lang::Kernel: |
#                                          | :LaunchContextBuilder&), pybind11::name const |
#                                          | &, pybind11::is_method const&, pybind11::sibl |
#                                          | ing const&)::'lambda'(pybind11::detail::funct |
#                                          | ion_call&)::__invoke(pybind11::detail::functi |
#                                          | on_call&)                                     |
# *               taichi_core.so |    4075 | pybind11::cpp_function::dispatcher(_object*,  |
#                                          | _object*, _object*)                           |
# *                      Python3 |     492 | (null)                                        |
# *                      Python3 |     270 | (null)                                        |
# *                      Python3 |     131 | (null)                                        |
# *                      Python3 |     136 | (null)                                        |
# *                      Python3 |     198 | (null)                                        |
# *                      Python3 |     575 | (null)                                        |
# *                      Python3 |     773 | (null)                                        |
# *                      Python3 |   28520 | (null)                                        |
# *                      Python3 |    2888 | (null)                                        |
# *                      Python3 |     455 | (null)                                        |
# *                      Python3 |   29134 | (null)                                        |
# *                      Python3 |    2888 | (null)                                        |
# *                      Python3 |     455 | (null)                                        |
# *                      Python3 |   29134 | (null)                                        |
# *                      Python3 |    2888 | (null)                                        |
# *                      Python3 |     455 | (null)                                        |
# *                      Python3 |     131 | (null)                                        |
# *                      Python3 |     169 | (null)                                        |
# *                      Python3 |     136 | (null)                                        |
# *                      Python3 |   29134 | (null)                                        |
# *                      Python3 |    2888 | (null)                                        |
# *                      Python3 |     228 | (null)                                        |
# *                      Python3 |     780 | (null)                                        |
# *                      Python3 |   28520 | (null)                                        |
# *                      Python3 |    2888 | (null)                                        |
# *                      Python3 |     228 | (null)                                        |
# *                      Python3 |     780 | (null)                                        |
# *                      Python3 |   28692 | (null)                                        |
# *                      Python3 |    2888 | (null)                                        |
# *                      Python3 |     228 | (null)                                        |
# *                      Python3 |     780 | (null)                                        |
# *                      Python3 |   28692 | (null)                                        |
# *                      Python3 |     237 | (null)                                        |
# *                      Python3 |     780 | (null)                                        |
# *                      Python3 |   28520 | (null)                                        |
# *                      Python3 |    2888 | (null)                                        |
# *                      Python3 |      48 | (null)                                        |
# *                      Python3 |     583 | (null)                                        |
# *                      Python3 |     661 | (null)                                        |
# *                      Python3 |      41 | (null)                                        |
# *                      Python3 |     656 | (null)                                        |
# *                      Python3 |   28520 | (null)                                        |
# *                      Python3 |    2888 | (null)                                        |
# *                      Python3 |     228 | (null)                                        |
# *                      Python3 |     780 | (null)                                        |
# *                      Python3 |   28360 | (null)                                        |
# *                      Python3 |    2888 | (null)                                        |
# *                      Python3 |     228 | (null)                                        |
# *                      Python3 |     780 | (null)                                        |
# *                      Python3 |   28692 | (null)                                        |
# *                      Python3 |    2888 | (null)                                        |
# *                      Python3 |     228 | (null)                                        |
# *                      Python3 |     780 | (null)                                        |
# *                      Python3 |   28520 | (null)                                        |
# *                      Python3 |    2888 | (null)                                        |
# *                      Python3 |     455 | (null)                                        |
# *                      Python3 |   29134 | (null)                                        |
# *                      Python3 |    2888 | (null)                                        |
# *                      Python3 |     228 | (null)                                        |
# *                      Python3 |     780 | (null)                                        |
# *                      Python3 |   28520 | (null)                                        |
# *                      Python3 |    2888 | (null)                                        |
# *                      Python3 |     455 | (null)                                        |
# *                      Python3 |     131 | (null)                                        |
# *                      Python3 |     136 | (null)                                        |
# *                      Python3 |   29134 | (null)                                        |
# *                      Python3 |    2888 | (null)                                        |
# *                      Python3 |     228 | (null)                                        |
# *                      Python3 |     780 | (null)                                        |
# *                      Python3 |   28331 | (null)                                        |
# *                      Python3 |    2888 | (null)                                        |
# *                      Python3 |      48 | (null)                                        |
# *                      Python3 |     583 | (null)                                        |
# *                      Python3 |     661 | (null)                                        |
# *                      Python3 |      41 | (null)                                        |
# *                      Python3 |     656 | (null)                                        |
# *                      Python3 |   28520 | (null)                                        |
# *                      Python3 |     242 | (null)                                        |
# *                      Python3 |   11906 | (null)                                        |
# *                      Python3 |     242 | (null)                                        |
# *                      Python3 |   11906 | (null)                                        |
# *                      Python3 |     242 | (null)                                        |
# *                      Python3 |     775 | (null)                                        |
# *                      Python3 |      81 | (null)                                        |
# *                      Python3 |     827 | (null)                                        |
# *                      Python3 |   28331 | (null)                                        |
# *                      Python3 |     237 | (null)                                        |
# *                      Python3 |     780 | (null)                                        |
# *                      Python3 |   28520 | (null)                                        |
# *                      Python3 |     237 | (null)                                        |
# *                      Python3 |     780 | (null)                                        |
# *                      Python3 |   28331 | (null)                                        |
# *                      Python3 |    2888 | (null)                                        |
# *                      Python3 |     455 | (null)                                        |
# *                      Python3 |     131 | (null)                                        |
# *                      Python3 |     136 | (null)                                        |
# *                      Python3 |   29134 | (null)                                        |
# *                      Python3 |    2888 | (null)                                        |
# *                      Python3 |     228 | (null)                                        |
# *                      Python3 |     780 | (null)                                        |
# *                      Python3 |   28692 | (null)                                        |
# *                      Python3 |     242 | (null)                                        |
# *                      Python3 |     100 | (null)                                        |
# *                      Python3 |     661 | (null)                                        |
# *                      Python3 |      41 | (null)                                        |
# ==========================================================================================
#
#
# Internal Error occurred, check this page for possible solutions:
# https://taichi.readthedocs.io/en/stable/install.html#troubleshooting

# %% [markdown]
# # mass_spring_rs.py

# %% [markdown]
# Changes: Tried using numpy RandomState(seed=10) instead of np.random.seed()
#
# Observation: Weight initialization are the same between runs. Loss outputs are different. No improvement from mass_spring.py

# %% [markdown]
# ### Run 1:

# %%
# %run -i mass_spring_rs.py 2 train
# Out:
# [Taichi] mode=release
# [Taichi] preparing sandbox at /var/folders/hm/8lv3n72d13756xxcw59843d82j2gcf/T/taichi-1emb8fjj
# [Taichi] version 0.6.28, llvm 10.0.0, commit 2670350d, osx, python 3.7.3
# [Taichi] Starting on arch=x64
# n_objects= 20    n_springs= 46
# [Taichi] materializing...
# weights1 [[ 3.3822331e-01  1.8168104e-01 -3.9253208e-01 ... -5.0657654e-01
#    2.8135818e-01  6.2114231e-02]
#  [-1.5725670e-02 -1.9148900e-01  1.8083777e-01 ... -1.7245266e-01
#    1.3560687e-01  1.8896969e-01]
#  [ 5.6516320e-01  2.9764110e-02  6.2132150e-02 ... -2.9179862e-01
#   -2.1221937e-01  5.3454537e-02]
#  ...
#  [-2.3094121e-01 -1.7427291e-01  4.5793399e-02 ...  7.6144665e-02
#    7.1664438e-02 -1.7625408e-01]
#  [ 1.3940075e-01 -2.6423591e-01 -4.0664431e-02 ... -2.1034110e-01
#    9.3053527e-02 -4.0628552e-02]
#  [-6.3465840e-01  2.5919918e-04 -5.2990668e-02 ...  2.4079077e-01
#   -1.0515716e-01 -1.3480270e-01]]
# weights2 [[-0.06632762  0.36805248 -0.8220521  ...  0.12049739 -0.8172988
# ...

# %% [markdown]
# ### Run 2:

# %%
# %run -i mass_spring_rs.py 2 train
# Out:
# [Taichi] Starting on arch=x64
# n_objects= 20    n_springs= 46
# [Taichi] materializing...
# weights1 [[ 3.3822331e-01  1.8168104e-01 -3.9253208e-01 ... -5.0657654e-01
#    2.8135818e-01  6.2114231e-02]
#  [-1.5725670e-02 -1.9148900e-01  1.8083777e-01 ... -1.7245266e-01
#    1.3560687e-01  1.8896969e-01]
#  [ 5.6516320e-01  2.9764110e-02  6.2132150e-02 ... -2.9179862e-01
#   -2.1221937e-01  5.3454537e-02]
#  ...
#  [-2.3094121e-01 -1.7427291e-01  4.5793399e-02 ...  7.6144665e-02
#    7.1664438e-02 -1.7625408e-01]
#  [ 1.3940075e-01 -2.6423591e-01 -4.0664431e-02 ... -2.1034110e-01
#    9.3053527e-02 -4.0628552e-02]
#  [-6.3465840e-01  2.5919918e-04 -5.2990668e-02 ...  2.4079077e-01
#   -1.0515716e-01 -1.3480270e-01]]
# weights2 [[-0.06632762  0.36805248 -0.8220521  ...  0.12049739 -0.8172988
#   -0.14953314]
#  [-0.53876334  0.01549972  1.142494   ... -1.3020005   0.18299296
#    0.22064199]
#  [ 0.2567513   0.1025689   0.2639111  ... -0.45838857  0.01203695
#    0.10466623]
#  ...
# ...

# %% [markdown]
# # mass_spring_rs_old_syn.py

# %% [markdown]
# Change: uses .var instead of .field
#
# Observation: Results are not exactly the same, but much closer than before

# %% [markdown]
# ### run 1:

# %%
# %run -i mass_spring_rs_old_syn.py 2 train
# Out:
# [Taichi] Starting on arch=x64
# n_objects= 20    n_springs= 46
# [Taichi] materializing...
# mass_spring_rs_old_syn.py:206: DeprecationWarning: ti.veci(x, y) is deprecated, please use ti.core_veci(x, y) instead
#   gui = ti.core.GUI("Mass Spring Robot", ti.veci(1024, 1024))
# weights1 [[ 0.40148842  0.21566473 -0.46595573 -0.00252783  0.18733984 -0.21711397
#    0.08005475  0.03272861  0.00129392 -0.05264394  0.1305623   0.36272943
#   -0.29097825  0.3100363   0.06893457  0.13421404 -0.34269845  0.0407453
#    0.44760475 -0.3255734  -0.5963075  -0.5256465   0.08022317  0.7190947
#    0.33880568  0.5043146   0.02989461  0.42151177 -0.08178435  0.18488802
#   -0.08059917 -0.1656229   0.04001306 -0.14356221  0.39451948  0.05879872
#    0.12066785 -0.10179998  0.37884066 -0.2206971   0.19906731 -0.10579186
#   -0.28324983 -0.14754072 -0.24259336 -0.06413075 -0.10225463  0.09412277
#    0.17039993 -0.04444888 -0.00781075  0.08716518 -0.16277966  0.21351828
# ...

# %% [markdown]
# ### run 2:

# %%
# %run -i mass_spring_rs_old_syn.py 2 train
# Out:
# [Taichi] Starting on arch=x64
# n_objects= 20    n_springs= 46
# [Taichi] materializing...
# mass_spring_rs_old_syn.py:206: DeprecationWarning: ti.veci(x, y) is deprecated, please use ti.core_veci(x, y) instead
#   gui = ti.core.GUI("Mass Spring Robot", ti.veci(1024, 1024))
# weights1 [[ 0.40148842  0.21566473 -0.46595573 -0.00252783  0.18733984 -0.21711397
#    0.08005475  0.03272861  0.00129392 -0.05264394  0.1305623   0.36272943
#   -0.29097825  0.3100363   0.06893457  0.13421404 -0.34269845  0.0407453
#    0.44760475 -0.3255734  -0.5963075  -0.5256465   0.08022317  0.7190947
#    0.33880568  0.5043146   0.02989461  0.42151177 -0.08178435  0.18488802
#   -0.08059917 -0.1656229   0.04001306 -0.14356221  0.39451948  0.05879872
#    0.12066785 -0.10179998  0.37884066 -0.2206971   0.19906731 -0.10579186
#   -0.28324983 -0.14754072 -0.24259336 -0.06413075 -0.10225463  0.09412277
#    0.17039993 -0.04444888 -0.00781075  0.08716518 -0.16277966  0.21351828
# ...
